# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

cplusplus = [0.0002, 0.0016, 0.0102, 0.0242, 0.0454, 0.0698,0.107,0.142,0.187,0.2466,0.295,1.137,2.679,4.9324,4.2508]
golangL = [0.0000002,0.0004465,0.00076118,0.00293846,0.0015073,0.0019066,0.0027046,0.0035054599999999997,0.00313346,0.00379822,0.00824912,0.0085959,0.01200128,0.02119812,0.019599079999999998]
pythonL = [0.00100408,0.0766014,0.408625,1.06069,1.83653,2.92558,4.23121,5.7844,7.59435,9.81185,12.5024,46.8308,114.431,206.628,184.463]
datosE = [100, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000]

cplusplus = [0.000447214,0.000547723,0.00083666,0.00083666,0.00207364,0.00083666,0.00678233,0.00316228,0.00367423,0.0186091,0.00463681,0.0317096,0.0580991,0.0461335,0.0671245]
golangL = [0,0.0009984043519536562,0.0017020502231132899,0.006570596309164032,0.0033704252624854334,0.004263287205901099,0.0060476694519459315,0.007838446852406412,0.007006629564776491,0.008493078113499251,0.018445593074553065,0.019221016727790443,0.026835677897008674,0.047400437315197844,0.04382487517645658]
pythonL = [0.0000105034,0.00461269,0.00815552,0.0371665,0.0235117,0.0462259,0.104465,0.160853,0.0836083,0.350118,0.618652,0.746774,3.64621,1.96436,2.56335]

plt.plot(datosE, cplusplus, marker='h', linestyle='-', color='b', label='C++')
plt.plot(datosE, golangL,  marker='o', linestyle='-', color='c', label='Golang')
plt.plot(datosE, pythonL,  marker='D', linestyle='-', color='y', label='Python')


plt.xlabel('Datos de Entrada')
plt.ylabel('Tiempo de Ejecucion - Promedio de 5 iteraciones (s)')
plt.title('Comparacion de Tiempos de Entrada')
plt.legend(loc='upper left')

plt.show()

# %%
x=["C++","Golang","Python"]
y=[4.2508,0.019599079999999998,184.463]
plt.bar(x,y)
plt.title('Comparacion de Tiempos con entrada de 50000 elementos')
plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

cplusplus = [0.000000,0.000000,0.000400,0.000400,0.000800,0.001000,0.001000,0.002000,0.002200,0.002600,0.002800,0.004600,0.007200,0.011000,0.010800]
golangL = [0,0.0001967,0,0.00019742000000000002,0.00040008000000000003,0.0009999000000000002,0.0004018,0.00060324,0.00040178,0.0005999800000000001,0.00060158,0.0015106999999999998,0.0018048799999999996,0.00240008,0.00320328]
pythonL = [0.00020012855529785156,0.0032030582427978516,0.007203006744384765,0.01859903335571289,0.020397233963012695,0.020998382568359376,0.03259859085083008,0.04120383262634277,0.049800539016723634,0.0533998966217041,0.0679966926574707,0.10440340042114257,0.15939602851867676,0.25059995651245115,0.2457973003387451]
datosE = [100, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000]

plt.plot(datosE, cplusplus, marker='h', linestyle='-', color='b', label='C++')
plt.plot(datosE, golangL,  marker='o', linestyle='-', color='c', label='Golang')
#plt.plot(datosE, pythonL,  marker='D', linestyle='-', color='y', label='Python')

plt.xlabel('Datos de Entrada')
plt.ylabel('Tiempo de Ejecucion - Promedio de 5 iteraciones (s)')
plt.title('Comparacion de Tiempos de Entrada')
plt.legend(loc='upper left')

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

cplusplus = [0.000000,0.000000,0.000548,0.000548,0.000447,0.000000,0.000000,0.000000,0.000447,0.000548,0.000447,0.000548,0.000447,0.000000,0.000447]
golangL = [0,0.0004398345711742087,0,0.0004414445401180085,0.0005478326541928657,0.000352703841770967,0.0005501889493619442,0.000550763568148802,0.0005501719749314754,0.0005477473979856042,0.0005491754837936595,0.0004999190884533216,0.00044448697056269273,0.0005394693476000282,0.0004484163322181743]
pythonL = [0.00044750105388482173,0.0004488231999623418,0.001091162820092643,0.017558699992634763,0.004339802227166203,0.0000046586282660303,0.0008895116907436528,0.0008380693624962974,0.0011020818628026633,0.002190905580363377,0.0015753073430149016,0.0033638437470697663,0.0016763173470736774,0.006692692092339291,0.005356526901118647]
datosE = [100, 1000, 2000, 3000, 4000, 5000, 6000, 7000, 8000, 9000, 10000, 20000, 30000, 40000, 50000]

plt.plot(datosE, cplusplus, marker='h', linestyle='-', color='b', label='C++')
plt.plot(datosE, golangL,  marker='o', linestyle='-', color='c', label='Golang')
plt.plot(datosE, pythonL,  marker='D', linestyle='-', color='y', label='Python')

plt.xlabel('Datos de Entrada')
plt.ylabel('Tiempo de Ejecucion - Promedio de 5 iteraciones (s)')
plt.title('Comparacion de Tiempos de Entrada')
plt.legend(loc='upper left')

plt.show()
